# %% [markdown]
# <a href="https://colab.research.google.com/github/bsguarda/data_science/blob/main/An%C3%A1lise_do_Covid_19_2022.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# * [Bruno Guarda](encurtador.com.br/nsPTZ)
#
# ---

# %% [markdown]
# # Panorama do COVID-19
#
# A COVID-19 é uma doença infecciosa que provoca febre, cansaço, tosse seca, em casos mais graves, falta de ar, e é causada pelo novo coronavírus, o SARS-CoV-2, potencialmente grave e com elevada transmissibilidade e de distribuição global.
#
#  Se tornou pandemia em março de 2020, mas surgiu em dezembro de 2019 na China. À medida que a doença avançava, novas orientações eram vinculadas, visando a prevenção e um número menor de internações, e mortes.
#
#   Entretanto, muita gente resistiu e ainda resiste às orientações, acabando indo contra as instruções dos especialistas, piorando assim, o quadro sanitário de determinados locais. Enquanto o vírus SARS-CoV-2 se disseminava, os cientistas testaram vários medicamentos para desacelerar a mortalidade global, alguns mostraram bons resultados in vitro, no entanto, não obtiveram resultados promissores quando testados in vivo ou em testes com seres humanos.
#
# <center><img alt="Colaboratory logo" width="90%" src="https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQsN3bOqbf1O4x_8S3r01NzckL1di4HpCixIA&usqp=CAU"></center>
#
# Até o presente momento, cerca de 12 bilhões de pessoas no mundo já foram vacinadas com pelo menos uma dose, cerva de 4,72 bilhões de pessoas já estão totalmente vacinadas e esses números nos mostram que cerca de 61,2% da população mundial está vacinada.
#
# No Brasil cerca de 449 milhões de doses foram aplicadas, 169 milhões de pessoas estão totalmente vacinadas e cerca de 79,2% da população brasileira está vacinada.
#
# Irei realizar uma análise a respeito do COVID-19, trazendo informações do contexto mundial e também no Brasil, utilizando os dados públicos sobre a doença.

# %% [markdown]
# ###Obtenção dos dados
#
# * *Utilizaremos nessa análise o dataset direto do repositorio da [Our Word Data](https://ourworldindata.org/) que é especializada em expor pesquisas empíricas e dados analíticos, trazendo dados atualizados e seguros.*
#
# Os datasets públicos tem alguns problemas de formatação, diferença de inserção de dados, falta de dados e acaba deixando a exploração dos dados um pouco confusa no momento da análise.

# %% [markdown]
# ###Importando as bibliotecas necessárias para a análise exploratória dos dados, são elas:
#
# * *Pandas*
#
# * *Matplotlib*
#
# * *Seaborn*
#
# * *Numpy*

# %%
#Importando as bibliotecas
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

sns.set_style()

import warnings
warnings.filterwarnings('ignore')

# %matplotlib inline

# %% [markdown]
# ###Importando o data set
#
# O dataset pode ser obtido através [desse link](https://raw.githubusercontent.com/owid/covid-19-data/master/public/data/owid-covid-data.csv')

# %%
#Importandos o dataset e transformando em DataFrame (df)
df = pd.read_csv('https://raw.githubusercontent.com/owid/covid-19-data/master/public/data/owid-covid-data.csv')

# %% [markdown]
# #Análise Exploratória dos Dados
#
# Vamos verificar o tamanho do dataset e observar inicialmente as primeiras entradas dele.
#
# Podemos verificar que o dataset tem:
#
# * *194977 entradas*
# * *67 variáveis*

# %%
#Tamanho do datset

print(f'O Dataset possui: \n{df.shape[0]} entradas \n{df.shape[1]} variáveis')

#Verificando as 5 primeiras linhas do df
df.head()
# Out:
# O Dataset possui:
# 194977 entradas
# 67 variáveis
#   iso_code continent     location        date  total_cases  new_cases  \
# 0      AFG      Asia  Afghanistan  2020-02-24          5.0        5.0
# 1      AFG      Asia  Afghanistan  2020-02-25          5.0        0.0
# 2      AFG      Asia  Afghanistan  2020-02-26          5.0        0.0
# 3      AFG      Asia  Afghanistan  2020-02-27          5.0        0.0
# 4      AFG      Asia  Afghanistan  2020-02-28          5.0        0.0
#
#    new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0                 NaN           NaN         NaN                  NaN  ...
# 1                 NaN           NaN         NaN                  NaN  ...
# 2                 NaN           NaN         NaN                  NaN  ...
# 3                 NaN           NaN         NaN                  NaN  ...
# 4                 NaN           NaN         NaN                  NaN  ...
#
# ...

# %% [markdown]
# ###Dicionário de Variáveis
#
# `iso_code` - ISO 3166-1 alfa-3 - códigos de países de três letras
#
# `continent` - Continente da localização geográfica
#
# `location` - Localização geográfica
#
# `date` - Data de observação
#
# `total_cases` - Total de casos confirmados de COVID-19
#
# `new_cases` - Novos casos confirmados de COVID-19
#
# `new_cases_smoothed` - Novos casos confirmados de COVID-19 (7 dias suavizados)
#
# `total_deaths` - Total de mortes atribuídas à COVID-19
#
# `new_deaths` - Novas mortes atribuídas à COVID-19
#
# `new_deaths_smoothed` - Novas mortes atribuídas à COVID-19 (7 dias suavizados)
#
# `total_cases_per_million` - Total de casos confirmados de COVID-19 por 1.000.000 de pessoas
#
# `new_cases_per_million` - Novos casos confirmados de COVID-19 por 1.000.000 de pessoas
#
# `new_cases_smoothed_per_million` - Novos casos confirmados de COVID-19 (7 dias suavizados) por 1.000.000 de pessoas
#
# `total_deaths_per_million` - Total de mortes atribuídas à COVID-19 por 1.000.000 de pessoas
#
# `new_deaths_per_million` - Novas mortes atribuídas à COVID-19 por 1.000.000 de pessoas
#
# `new_deaths_smoothed_per_million` - Novas mortes atribuídas à COVID-19 (7 dias suavizados) por 1.000.000 de pessoas
#
# `reproduction_rate` - Estimativa em tempo real da taxa de reprodução efetiva (R) da COVID-19
#
# `icu_patients` - Número de pacientes COVID-19 em unidades de terapia intensiva (UTIs) em um determinado dia
#
# `icu_patients_per_million` - Número de pacientes COVID-19 em unidades de terapia intensiva (UTIs) em um determinado dia por 1.000.000 de pessoas
#
# `hosp_patients` - Número de pacientes da COVID-19 no hospital em um determinado dia
#
# `hosp_patients_per_million` - Número de pacientes COVID-19 no hospital em um determinado dia por 1.000.000 de pessoas
#
# `weekly_icu_admissions` - Número de pacientes COVID-19 recém admitidos em unidades de terapia intensiva (UTIs) em uma determinada semana
#
# `weekly_icu_admissions_per_million` - Número de pacientes COVID-19 recém admitidos (UTIs) em uma determinada semana por 1.000.000 de pessoas
#
# `weekly_hosp_admissions` - Número de pacientes COVID-19 recém admitidos em hospitais em uma determinada semana
#
# `weekly_hosp_admissions_per_million` - Número de pacientes COVID-19 recém admitidos em hospitais em uma determinada semana por 1.000.000 de pessoas
#
# `total_tests` - Testes totais para a COVID-19
#
# `new_tests` - Novos testes para a COVID-19 (apenas calculados para dias consecutivos)
#
# `total_tests_per_thousand` - Testes totais para COVID-19 por 1.000 pessoas
#
# `new_tests_per_thousand` - New tests for COVID-19 per 1,000 people
#
# `new_tests_smoothed` - Novos testes para a COVID-19 (7 dias suavizados).
#
# `new_tests_smoothed_per_thousand` - Novos testes para COVID-19 (7 dias suavizados) por 1.000 pessoas
#
# `positive_rate` - A parte dos testes COVID-19 que são positivos, dada como média móvel de 7 dias (este é o inverso dos tests_per_case)
#
# `tests_per_case` - Testes realizados por novo caso confirmado de COVID-19, dado como uma média móvel de 7 dias (este é o inverso de positive_rate)
#
# `tests_units` - Unidades utilizadas pelo local para relatar seus dados de teste
#
# `total_vaccinations` - Número total de doses de vacinação COVID-19 administradas
#
# `people_vaccinated` - Número total de pessoas que receberam pelo menos uma dose de vacina
#
# `people_fully_vaccinated` - Número total de pessoas que receberam todas as doses prescritas pelo protocolo de vacinação
#
# `new_vaccinations` - Novas doses de vacinação COVID-19 administradas (apenas calculadas para dias consecutivos)
#
# `new_vaccinations_smoothed` - Novas doses de vacinação COVID-19 administradas (7 dias suavizadas).
#
# `total_vaccinations_per_hundred` - Número total de doses de vacinação COVID-19 administradas por 100 pessoas na população total
#
# `people_vaccinated_per_hundred` - Número total de pessoas que receberam pelo menos uma dose de vacina por 100 pessoas na população total
#
# `people_fully_vaccinated_per_hundred` - Número total de pessoas que receberam todas as doses prescritas pelo protocolo de vacinação por 100 pessoas na população total
#
# `new_vaccinations_smoothed_per_million` - Novas doses de vacinação COVID-19 administradas (7 dias suavizadas) por 1.000.000 de pessoas na população total
#
# `stringency_index` - Índice de Estringência de Resposta do Governo: medida composta baseada em 9 indicadores de resposta, incluindo fechamento de escolas, fechamento de locais de trabalho e proibição de viagens, redimensionada para um valor de 0 a 100 (100 = resposta mais estrita)
#
# `population` - População
#
# `population_density` - Número de pessoas dividido por área de terreno, medido em quilômetros quadrados, ano mais recente disponível
#
# `median_age` - Idade média da população
#
# `aged_65_older` - Parte da população com 65 anos de idade ou mais, ano mais recente disponível
#
# `aged_70_older` - Participação da população com 70 anos de idade ou mais em 2015
#
# `gdp_per_capita` - Produto interno bruto em paridade de poder de compra (dólar internacional constante em 2011), ano mais recente disponível
#
# `extreme_poverty` - Participação da população vivendo em extrema pobreza, ano mais recente disponível desde 2010
#
# `cardiovasc_death_rate` - Taxa de mortalidade por doença cardiovascular em 2017 (número anual de mortes por 100.000 pessoas)
#
# `diabetes_prevalence` - Prevalência do diabetes (% da população de 20 a 79 anos de idade) em 2017
#
# `female_smokers` - Participação de mulheres que fumam, ano mais recente disponível
#
# `male_smokers` - Participação de homens que fumam, ano mais recente disponível
#
# `handwashing_facilities` - Parte da população com instalações básicas de lavagem de mãos nas instalações, o ano mais recente disponível
#
# `hospital_beds_per_thousand` - Leitos hospitalares por 1.000 pessoas, o ano mais recente disponível desde 2010
#
# `life_expectancy` - Expectativa de vida ao nascer em 2019
#
# `human_development_index` - Um índice composto que mede o desempenho médio em três dimensões básicas do desenvolvimento humano - uma vida longa e saudável, conhecimento e um padrão de vida decente.

# %%
#Verificando a colunas do DataFrame
df.columns
# Out:
# Index(['iso_code', 'continent', 'location', 'date', 'total_cases', 'new_cases',
#        'new_cases_smoothed', 'total_deaths', 'new_deaths',
#        'new_deaths_smoothed', 'total_cases_per_million',
#        'new_cases_per_million', 'new_cases_smoothed_per_million',
#        'total_deaths_per_million', 'new_deaths_per_million',
#        'new_deaths_smoothed_per_million', 'reproduction_rate', 'icu_patients',
#        'icu_patients_per_million', 'hosp_patients',
#        'hosp_patients_per_million', 'weekly_icu_admissions',
#        'weekly_icu_admissions_per_million', 'weekly_hosp_admissions',
#        'weekly_hosp_admissions_per_million', 'total_tests', 'new_tests',
#        'total_tests_per_thousand', 'new_tests_per_thousand',
#        'new_tests_smoothed', 'new_tests_smoothed_per_thousand',
#        'positive_rate', 'tests_per_case', 'tests_units', 'total_vaccinations',
#        'people_vaccinated', 'people_fully_vaccinated', 'total_boosters',
# ...

# %% [markdown]
# Um ponto crucial da análise é verificar e gaarantir que as variáveis estão no melhor formato para serem explorados.
#
# Vamos utilizar o método `dtypes`

# %%
#Verificando os tipos das variáveis que formam o DataFrame 
df.dtypes
# Out:
# iso_code                                    object
# continent                                   object
# location                                    object
# date                                        object
# total_cases                                float64
#                                             ...
# human_development_index                    float64
# excess_mortality_cumulative_absolute       float64
# excess_mortality_cumulative                float64
# excess_mortality                           float64
# excess_mortality_cumulative_per_million    float64
# Length: 67, dtype: object

# %% [markdown]
# Através do método dtypes podemos ver que o formato da data está em formato de objeto, vamos transforma-lo em formato de data através do método `datetime` da biblioteca Pandas

# %%
#Transformando a coluna de data em formato datetime
df.date = pd.to_datetime(df.date)

# %% [markdown]
# Um detalhe que não pode ser descartado durante a análise é a verificação dos dados faltantes. Temos que ter bastante atenção sobre esse ponto pois esses dados faltantes afetam diretamente na análise. Então devemos saber quais dados estão faltando e o motivo deles estarem faltando.
#
# Importe verificar diretamente na fonte dos dados no intuito de entender como é feita essa coleta, verificar o motivo desses dados faltantes se eles são aleatórios ou são pontuais.

# %%
#Identificando a quantidade de dados ausentes
round((df.isnull().sum() / df.shape[0]).sort_values(ascending=False),2)[:20]
# Out:
# weekly_icu_admissions                      0.97
# weekly_icu_admissions_per_million          0.97
# excess_mortality_cumulative_absolute       0.97
# excess_mortality_cumulative_per_million    0.97
# excess_mortality_cumulative                0.97
# excess_mortality                           0.97
# weekly_hosp_admissions_per_million         0.94
# weekly_hosp_admissions                     0.94
# total_boosters_per_hundred                 0.87
# total_boosters                             0.87
# icu_patients                               0.87
# icu_patients_per_million                   0.87
# hosp_patients_per_million                  0.86
# hosp_patients                              0.86
# new_vaccinations                           0.77
# people_fully_vaccinated_per_hundred        0.75
# people_fully_vaccinated                    0.75
# people_vaccinated                          0.74
# people_vaccinated_per_hundred              0.74
# total_vaccinations                         0.73
# ...

# %% [markdown]
# Podemos notar que existem nesse dataset varias variaveis que tem quase que sua totalidade de dados ausentes.
#
# A exemplo temos:
#
# weekly_icu_admissions, weekly_icu_admissions_per_million, excess_mortality_cumulative_absolute, excess_mortality_cumulative_per_million,excess_mortality_cumulative e excess_mortality estão com quase 98% dos dados faltantes então acabam não agregando nenhum valor para análise e podem serem excluídas.
#
#
# weekly_hosp_admissions_per_million e weekly_hosp_admissions tem 94% dos valores ausentes e poderam ser excluidas
#
#
# total_boosters_per_hundred, total_boosters icu_patients, icu_patients_per_million, hosp_patients_per_million e hosp_patients têm 87% dos valores ausentes e fazem referêcia a apenas um único dia de resgistro não trazendo relevancia a análise.

# %%
#Verificando a data mais atual do dataset
df.date.max()
# Out:
# '2022-06-18'

# %% [markdown]
# Iremos filtrar o DataFrame para verificarmos os países com mais casos e mortes e fazer o Top 5 com esses dados para plotarmos um gráfico mais explicativo.
#
# Vamos atribuir no nome `df_final` o DataFrame já filtrado.

# %%
remove = df.loc[(df['location'] == 'World') | (df['location'] == 'Asia') | (df['location'] == 'High income') | (df['location'] == 'Europe') |
(df['location'] =='European Union') | (df['location'] == 'Upper middle income') | (df['location'] =='North America') |(df['location'] == 'Lower middle income') | (df['location'] == 'South America')]
df_final = df.drop(remove.index)

# %%
#Verificando qual país tem mais casos e de morte para a data mais atual do df
df_final.loc[df_final.date == '2022-06-18'].sort_values(by="total_cases", ascending=False)
df_final.loc[df_final.date == '2022-06-18'].sort_values(by="total_deaths", ascending=False)
# Out:
#        iso_code      continent              location        date  total_cases  \
# 184579      USA  North America         United States  2022-06-18   86230982.0
# 25192       BRA  South America                Brazil  2022-06-18   31611769.0
# 81446       IND           Asia                 India  2022-06-18   43296692.0
# 145813      RUS         Europe                Russia  2022-06-18   18126576.0
# 114171      MEX  North America                Mexico  2022-06-18    5852596.0
# ...         ...            ...                   ...         ...          ...
# 105853      MAC           Asia                 Macao  2022-06-18         83.0
# 111621      MHL        Oceania      Marshall Islands  2022-06-18         18.0
# 114685      FSM        Oceania  Micronesia (country)  2022-06-18         38.0
# 147290      SHN         Africa          Saint Helena  2022-06-18          4.0
# 189339      VAT         Europe               Vatican  2022-06-18         29.0
#
# ...

# %% [markdown]
# Vamos separar em um novo DataFrame com as informações do Top 5 países em quatidade de mortes e em quantidade de casos e nesses DF vão está incluso a população de cada país.
#
# Também vamos utilizar o método `set_option('float_format)` para ajustarmos o formato de visualização dos dados que estão extensos e estão sendo mostrados em potência.
#
# Ficando assim:
#
# * *top5mortes*
#
# * *top5casos*

# %%
top5mortes= df_final.loc[df_final.date == '2022-06-17', ['location', 'total_deaths', 'population']].sort_values(by='total_deaths', ascending=False)[0:5]
top5casos = df_final.loc[df_final.date == '2022-06-17', ['location', 'total_cases', 'population']].sort_values(by='total_cases', ascending=False)[0:5]
pd.set_option('float_format', '{:.0f}'.format)

# %%
#Verificando o top 5 mortes

top5mortes
# Out:
#              location  total_deaths  population
# 184578  United States       1013358   332915074
# 25191          Brazil        668693   213993441
# 81445           India        524840  1393409033
# 145812         Russia        372642   145912022
# 114170         Mexico        325340   130262220

# %% [markdown]
# #Notamos que os países que lideram os mortes até a data de 18 de junho de 2022 são:
#
# * Estados Unidos com 1.013.358 mortes
# * Brasil com 668.693 mortes
# * India com 524.840 mortes
# * Russia com 372.642 mortes
# * México com 325.340 mortes

# %%
#@title
# Gráfico top 5 mortes

# Configurando a visualização
# %config InlineBackend.figure_format = 'svg'

# Configuando fonte
plt.rcParams['font.family'] = 'sans-serif'

# Configurando cores
Red1, Red2, Red3, Red4, Red5 = "#210012", "#360821", "#4d012a", "#701e4b", "#a63a75"

# Ajustes para construção do gráfico
x = np.arange(len(top5mortes.location))
width_bar = 0.7

# Definindo cores

paises = [Red1, Red2, Red3, Red4, Red5]

#Criar um figura para o gráfico
fig, ax = plt.subplots(figsize=(7,5))

# Plot do gráfico

graf = ax.bar(x - width_bar * 0.0056, top5mortes.total_deaths, width_bar, color = paises, linewidth = 0.5)

# Defindo os labels dos eixos

labels = top5mortes.location
x = np.arange(len(top5mortes.location))
ax.set_xticks(x)
ax.set_xticklabels(labels, size = 14)

#Removendo as grades de eixos
for x in ['top', 'bottom', 'right', 'left']:
  ax.spines[x].set_visible(False)
plt.gca().axes.get_yaxis().set_visible(False)

#criar função para dar labels automaticamente
def autolabel(rects):
    for rect in rects:
        height = rect.get_height()
        ax.annotate(
                    f'{height:.0f}\n',
                    xy=(rect.get_x() + rect.get_width()/2,  height),
                    xytext=(0, -28),  # offset
                    textcoords="offset points",
                    ha='center',
                    va='bottom',
                    fontsize=12,
                    color="white",
                    )

autolabel(graf)

# plotar título
fig.suptitle('Top 5 países em quantidade de mortes', fontsize=14, fontweight='bold', y = 0.95, color = 'k')
plt.style.use('seaborn-dark-palette');
fig.tight_layout()

# %%
#Verificando top 5 casos
top5casos
# Out:
#              location  total_cases  population
# 184578  United States     86216418   332915074
# 81445           India     43283793  1393409033
# 25191          Brazil     31611769   213993441
# 62479          France     30139875    67422000
# 66676         Germany     27204953    83900471

# %% [markdown]
# Já em relação aos casos temos que os países que estão no Top 5 são:
#
# * Estados Unidos com 86.216.418 casos
# * India com  43.283.793 casos
# * Brasil com 31.139.875 casos
# * França com 30.139.875
# * Alemanha com 27.204.953 casos

# %%
#@title
#Gráfico top 5 casos

# Configurando a visualização
# %config InlineBackend.figure_format = 'svg'

# Configuando fonte
plt.rcParams['font.family'] = 'sans-serif'

# Configurando cores
Red1, Red2, Red3, Red4, Red5 = "#210012", "#360821", "#4d012a", "#701e4b", "#a63a75"

# Ajustes para construção do gráfico
x = np.arange(len(top5casos.location))
width_bar = 0.7

# Definindo cores

paises = [Red1, Red2, Red3, Red4, Red5]

#Criar um figura para o gráfico
fig, ax = plt.subplots(figsize=(7,5))

# Plot do gráfico

graf = ax.bar(x - width_bar * 0.01, top5casos.total_cases, width_bar, color = paises, linewidth = 1)

# Defindo os labels dos eixos

labels = top5casos.location
x = np.arange(len(top5casos.location))
ax.set_xticks(x)
ax.set_xticklabels(labels, size = 14)

#Removendo as grades de eixos
for x in ['top', 'bottom', 'right', 'left']:
  ax.spines[x].set_visible(False)
plt.gca().axes.get_yaxis().set_visible(False)

#criar função para dar labels automaticamente
def autolabel(rects):
    for rect in rects:
        height = rect.get_height()
        ax.annotate(
                    f'{height:.0f}\n',
                    xy=(rect.get_x() + rect.get_width()/2,  height),
                    xytext=(0, -28),  # offset
                    textcoords="offset points",
                    ha='center',
                    va='bottom',
                    fontsize=12,
                    color="white",
                    )

autolabel(graf)

# plotar título
fig.suptitle('Top 5 países em quantidade de casos', fontsize=14, fontweight='bold', y = 0.9, color = 'k')
plt.style.use('seaborn-dark-palette');
fig.tight_layout()
plt.show()

# %% [markdown]
# Podemos observar no gráfico abaixo que em alguns países os casos corresporam a quase metade de sua população total (45%), como é o caso da França.

# %%
#@title
fig, ax = plt.subplots(figsize = (10,8))
width = 0.25

x = np.arange(len(top5casos.location))
y1 = top5casos.total_cases
y2 = top5casos.population
graf1 = ax.bar(x - 0.2,  y1, width, color = '#3b0422', label = 'Total de casos')
graf2 = ax.bar(x + 0.2,  y2, width, color = '#eb3107', label = 'População')
ax.legend()
labels = top5casos['location']
ax.set_xticks(x)
ax.set_xticklabels(labels, fontsize = 14)
def autolabel(rects):
    for rect in rects:
        height = rect.get_height()
        ax.annotate(
                    f'{height:.0f}\n',
                    xy=(rect.get_x() + rect.get_width()/2,  height),
                    xytext=(0, -10),  # offset
                    textcoords="offset points",
                    ha='center',
                    va='bottom',
                    fontsize=12,
                    color="black",
                    )
autolabel(graf1)
autolabel(graf2) 
#Removendo as grades de eixos
for x in ['top', 'bottom', 'right', 'left']:
  ax.spines[x].set_visible(False)
plt.gca().axes.get_yaxis().set_visible(False)   
fig.suptitle('Total de Casos x População', fontsize=14, fontweight='bold', x = 0.6, y = 0.8, color = 'k')
plt.style.use('seaborn-dark-palette')
plt.show()

# %% [markdown]
# Vamos plotar um gráfico de dispersão para confrontar suas variaveis, para entender se há uma relação. Vamos analisar o total de mortes com relação ao PIB dos países.
#
# Vimos que não há uma relação muito clara atraves desse gráfico relacionando essas duas variaveis.
#
# Lembrando que nada é conclusivo tendo em vista que muitos fatores estão envolvidos e a conclusão só deve vim através de testes.

# %%
pib = df_final.loc[df_final.date == '2022-06-17', ['location', 'total_cases', 'population', 'total_deaths', 'gdp_per_capita']].sort_values(by='total_cases', ascending=False)
pib.plot(kind="scatter", x ='gdp_per_capita', y = 'total_deaths', alpha =0.7, s=20, cmap=plt.get_cmap('jet'), figsize=(6,4))

# %% [markdown]
# ##Análise Exploratória para o Brasil
#
# Apresentando essa noção dos fatos no mundo, agora iremos fazer um overview dos acontecimentos no Brasil.

# %%
# Criando uma cópia do DataFrame com os dados apenas do Brasil

df_brasil  = df.loc[df.location == "Brazil"]

df_brasil.head()
# Out:
#       iso_code      continent location        date  total_cases  new_cases  \
# 24349      BRA  South America   Brazil  2020-02-26            1          1
# 24350      BRA  South America   Brazil  2020-02-27            1          0
# 24351      BRA  South America   Brazil  2020-02-28            1          0
# 24352      BRA  South America   Brazil  2020-02-29            2          1
# 24353      BRA  South America   Brazil  2020-03-01            2          0
#
#        new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 24349                 NaN           NaN         NaN                  NaN  ...
# 24350                 NaN           NaN         NaN                  NaN  ...
# 24351                 NaN           NaN         NaN                  NaN  ...
# 24352                 NaN           NaN         NaN                  NaN  ...
# 24353                 NaN           NaN         NaN                  NaN  ...
#
# ...

# %% [markdown]
# De acordo com o dataset o primeiro caso registrado no Brasil foi 26 de Fevereiro de 2020

# %%
df_brasil.loc[df_brasil['new_cases'] != 0.0].head(1)
print(f' O primeiro caso foi registrado em {df_brasil.date.loc[24349]}')
# Out:
#  O primeiro caso foi registrado em 2020-02-26 00:00:00

# %% [markdown]
# De acordo com esse dataset a primeira morte registrada no Brasil foi dia 17 de Março de 2020.

# %%
# Verificando quando foi resgistrada a primeira morte no Brasil
df_brasil.loc[df_brasil['total_deaths'] > 0.0][0:1]
print(f'A primeira morte foi resgistrada em {df_brasil.date.loc[24369]}')
# Out:
# A primeira morte foi resgistrada em 2020-03-17 00:00:00

# %% [markdown]
# Vamos identificar quanto tempo passou desde o primeiro caso até a primeira morte no Brasil.

# %%
from datetime import date

df_brasil.date = pd.to_datetime(df_brasil.date)

dias = df_brasil.date.loc[24369] - df_brasil.date.loc[24349]
print(f' Do primeiro caso até a primeira morte se passaram {dias.days} dias')
# Out:
#  Do primeiro caso até a primeira morte se passaram 20 dias

# %% [markdown]
# ###Conclusão
#
# Esses dados que estão expostos nesse dataset são medidos e atualizados diariamente
# então ele dicará desatualizado muito rápido.
#
# Porém através dessa análise podemos inferir que:
#
# * Os Estados Unidos é o país com mais casos e mais mortes.
#
# * Alguns países tiveram quase a metade da sua população contaminada com o vírus como é caso da França que teve 30.139.875 de casos e sua população é 67.422.000 ou seja 45% da população.
#
# * O Brasil mesmo com a quantidade de casos, população, e PIB per capita menor que a Índia conseguiu superar em número de mortes.
#
# * O México não apareceu entre o top 5 na quantidade de casos mas apareceu no top 5 em casos de mortes
